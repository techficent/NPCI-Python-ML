# %%
## to deal with data
import pandas as pd

#data visualization
import plotly.express as pe

#for the model
from sklearn.linear_model import LinearRegression

#for splitting the data
from sklearn.model_selection import train_test_split

#for evaluation
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### step 1: Source my data!

# %%
path = r"C:\Users\harsh\Desktop\NPCI-Python-ML\datasets\AAPL.csv"
apple_df = pd.read_csv(path, index_col='Date', parse_dates=True)
apple_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-02-14   16.590000   16.844286   16.572144   16.663929   14.392326
# 2013-02-15   16.744642   16.791430   16.425714   16.434286   14.193980
# 2013-02-19   16.467857   16.526072   16.208929   16.428213   14.188735
# 2013-02-20   16.346071   16.346071   16.028570   16.030357   13.845117
# 2013-02-21   15.928571   16.041786   15.815000   15.930714   13.759057
# ...                ...         ...         ...         ...         ...
# 2023-02-07  150.639999  155.229996  150.639999  154.649994  154.414230
# 2023-02-08  153.880005  154.580002  151.169998  151.919998  151.688400
# 2023-02-09  153.779999  154.330002  150.419998  150.869995  150.639999
# 2023-02-10  149.460007  151.339996  149.220001  151.009995  151.009995
# 2023-02-13  150.949997  154.259995  150.919998  153.850006  153.850006
#
#                Volume
# Date
# 2013-02-14  355275200
# 2013-02-15  391745200
# 2013-02-19  435783600
# ...

# %% [markdown]
# #### average opening price in 2018

# %%
apple_df.loc[  "2018" , ["Open"]   ].mean()
# Out:
# Open    47.277859
# dtype: float64

# %%
apple_df.shape
# Out:
# (2517, 6)

# %%
apple_df.index
# Out:
# DatetimeIndex(['2013-02-14', '2013-02-15', '2013-02-19', '2013-02-20',
#                '2013-02-21', '2013-02-22', '2013-02-25', '2013-02-26',
#                '2013-02-27', '2013-02-28',
#                ...
#                '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03',
#                '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                '2023-02-10', '2023-02-13'],
#               dtype='datetime64[ns]', name='Date', length=2517, freq=None)

# %%
apple_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
apple_df.nunique()
# Out:
# Open         2386
# High         2381
# Low          2392
# Close        2384
# Adj Close    2480
# Volume       2509
# dtype: int64

# %%
apple_df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2013-02-14 to 2023-02-13
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2517 non-null   float64
#  1   High       2517 non-null   float64
#  2   Low        2517 non-null   float64
#  3   Close      2517 non-null   float64
#  4   Adj Close  2517 non-null   float64
#  5   Volume     2517 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 137.6 KB

# %%
apple_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2517.000000  2517.000000  2517.000000  2517.000000  2517.000000
# mean     63.810860    64.540653    63.111178    63.855022    62.009138
# std      49.141068    49.798974    48.508160    49.182984    49.666314
# min      13.856071    14.271429    13.753571    13.947500    12.046192
# 25%      27.260000    27.547501    27.032499    27.277500    25.041708
# 50%      42.467499    42.805000    42.075001    42.330002    40.301655
# 75%     109.720001   111.989998   108.387497   110.062500   108.209015
# max     182.630005   182.940002   179.119995   182.009995   180.683853
#
#              Volume
# count  2.517000e+03
# mean   1.650414e+08
# std    1.129177e+08
# min    3.519590e+07
# 25%    9.042040e+07
# 50%    1.283368e+08
# 75%    2.001190e+08
# max    1.065523e+09

# %%
for col in apple_df.columns:

    display(       pe.box(data_frame=apple_df, y=col)           )

# %%
pe.scatter(x="Open", y="Close", data_frame=apple_df)

# %%
pe.scatter(x="Volume", y="Close", data_frame=apple_df)

# %%
apple_df[        ["Close", "Volume", "Open"]     ].corr()
# Out:
#            Close    Volume      Open
# Close   1.000000 -0.460762  0.999642
# Volume -0.460762  1.000000 -0.460178
# Open    0.999642 -0.460178  1.000000

# %%
condition = (   apple_df.index.month == 4  )

apple_df.loc[     condition       ]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-04-01   15.782143   15.846429   15.276429   15.318214   13.230055
# 2013-04-02   15.271429   15.647857   15.228571   15.349643   13.257196
# 2013-04-03   15.406071   15.617143   15.368214   15.428214   13.325058
# 2013-04-04   15.491429   15.535714   15.187500   15.275714   13.193347
# 2013-04-05   15.160714   15.176786   14.988571   15.114286   13.053924
# ...                ...         ...         ...         ...         ...
# 2022-04-25  161.119995  163.169998  158.460007  162.880005  161.899277
# 2022-04-26  162.250000  162.339996  156.720001  156.800003  155.855881
# 2022-04-27  155.910004  159.789993  155.380005  156.570007  155.627274
# 2022-04-28  159.250000  164.520004  158.929993  163.639999  162.654694
# 2022-04-29  161.839996  166.199997  157.250000  157.649994  156.700729
#
#                Volume
# Date
# 2013-04-01  389732000
# 2013-04-02  529519200
# 2013-04-03  363216000
# ...

# %%
apple_df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999863  0.999833  0.999642   0.999607 -0.460178
# High       0.999863  1.000000  0.999809  0.999834   0.999809 -0.457827
# Low        0.999833  0.999809  1.000000  0.999839   0.999798 -0.463302
# Close      0.999642  0.999834  0.999839  1.000000   0.999965 -0.460762
# Adj Close  0.999607  0.999809  0.999798  0.999965   1.000000 -0.461245
# Volume    -0.460178 -0.457827 -0.463302 -0.460762  -0.461245  1.000000

# %% [markdown]
# ### step 3: select features & target

# %%
feature = apple_df[    ["Open"]    ]
target = apple_df[    ["Close"]        ]

# %% [markdown]
# ### step 4: splitting the data

# %%
x_train, x_test, y_train, y_test=train_test_split(    feature, target, test_size=0.2, random_state=42     )

# %% [markdown]
# ### step 5: training the model

# %%
model = LinearRegression()

model.fit(  x_train, y_train      )
# Out:
# LinearRegression()

# %% [markdown]
# ### step 6: Evaluating the model

# %%
x_test
# Out:
#                   Open
# Date
# 2021-11-02  148.660004
# 2014-10-01   25.147499
# 2018-08-21   54.200001
# 2016-08-24   27.142500
# 2020-02-28   64.315002
# ...                ...
# 2016-07-19   24.889999
# 2020-04-30   72.489998
# 2013-04-30   15.539286
# 2020-10-23  116.389999
# 2015-02-03   29.625000
#
# [504 rows x 1 columns]

# %%
# Make a data frame of predicted close values
predicted_values_df = pd.DataFrame( model.predict(x_test), columns=["Predicted_Close"] )

#actual close values can be a data frame but their index is reset to avoid issues due to random sequence
actual_close_values_df = y_test.reset_index(drop=True)

#actual open values can be a data frame but their index is reset to avoid issues due to random sequence
actual_open_values_df = x_test.reset_index(drop=True)

#columns list to concatenate
cols = [actual_open_values_df, actual_close_values_df, predicted_values_df]

#use pd.concat to place columns SIDE BY SIDE , column wise [axis = 1]
result_df = pd.concat ( cols , axis=1     )

result_df
# Out:
#            Open       Close  Predicted_Close
# 0    148.660004  150.020004       148.747455
# 1     25.147499   24.795000        25.176475
# 2     54.200001   53.759998        54.242731
# 3     27.142500   27.007500        27.172420
# 4     64.315002   68.339996        64.362521
# ..          ...         ...              ...
# 499   24.889999   24.967501        24.918853
# 500   72.489998   73.449997        72.541388
# 501   15.539286   15.813571        15.563713
# 502  116.389999  115.040001       116.462173
# 503   29.625000   29.662500        29.656096
#
# [504 rows x 3 columns]

# %%
result_df[["Close","Predicted_Close"]].corr()
# Out:
#                     Close  Predicted_Close
# Close            1.000000         0.999655
# Predicted_Close  0.999655         1.000000

# %%
pe.line(     y=["Close","Predicted_Close"], data_frame=result_df    )

# %%
print(      mean_squared_error(y_test, predicted_values_df, squared=False)    )
# Out:
# 1.2633332449938668

# %% [markdown]
# # Close = slope * Open + Intercept
#
# # Y = m * X   + B

# %%
model.coef_  #slope
# Out:
# array([[1.00047344]])

# %%
model.intercept_ #intercept
# Out:
# array([0.01707009])
